# %%
import pandas as pd
import numpy as np

# playerName = input("Enter player in question: ")
playerName = "Aaron Judge"
playerName = playerName.split(' ')
playerName[1][0]
playerFirstTwoInit = ""
playerFirstTwoInit = playerName[1][0] + playerName[1][1].upper()
playerFirstTwoInit
# Out:
# 'JU'

# %%
# BAL2015GL = pd.read_csv("2015BAL.EVA")

file1 = open('2015SFN.EVN', 'r')
Lines = file1.readlines()
len(Lines)
cnt=0;

LineSubset = open("playerTest2.text",'w')
print('event,inning,home/away,retroSheetID,balls,strikes,play',file = LineSubset)

for i in range(len(Lines)):
    if "poseb001" in Lines[i]:
        linesplit = Lines[i].split()
        if linesplit != 'start':
            cnt = cnt+1;
            print(Lines[i],file = LineSubset)
        
# column_names = ["play", "inning", "home/away","retroSheetID","balls","strikes","play"]
# playerEventMatrix = pd.DataFrame(columns = column_names)

# data = pd.read_csv("playerTest2.csv")
# data

# %%
pd.read_csv("playerTest4.text")
# Out:
#        event inning    home/away retroSheetID balls         strikes  \
# 'play'   '1'    '1'   'poseb001'          '0'   '0'             'X'
# 'play'   '3'    '1'   'poseb001'          '0'   '1'            'CX'
# 'play'   '5'    '1'   'poseb001'          '0'   '1'            'CX'
# 'play'   '7'    '1'   'poseb001'          '1'   '2'         'FFFBS'
# 'play'   '8'    '1'   'poseb001'          '2'   '2'   '.1CSF*BFBFX'
# ...      ...    ...          ...          ...   ...             ...
# 'play'   '3'    '1'   'poseb001'          '0'   '1'           'C>X'
# 'play'   '6'    '1'   'poseb001'          '0'   '0'              ''
# 'play'   '6'    '1'   'poseb001'          '1'   '2'        '.BSFFX'
# 'play'   '7'    '1'   'poseb001'          '1'   '2'          'CTBX'
# 'play'   '9'    '1'   'poseb001'          '0'   '0'             'X'
#
#                play
# 'play'     '6/P/IF'
# 'play'       '53/G'
# 'play'        '9/F'
# 'play'          'K'
# 'play'        '8/F'
# ...             ...
# 'play'   'S8/F.1-3'
# 'play'         'NP'
# 'play'       '63/G'
# 'play'      '53/G-'
# 'play'       '53/G'
#
# [345 rows x 7 columns]
